# %%
# Дана функция f(x) = 5x^2 + 10x - 30

# 1. Определить корни

# 2. Найти интервалы, на которых функция возрастает

# 3. Найти интервалы, на которых функция убывает

# 4. Построить график

# 5. Вычислить вершину

# 6. Определить промежутки, на котором f > 0

# 7. Определить промежутки, на котором f < 0

# %%
# /

# %%
x= Symbol('x')
fun = 5*x**2 + 10*x - 30

# %%
# f = 5*x**2+10*x - 30
# f.subs(x, 10)
# Out:
# 570

# %%
# plot(f)   #график функции

# %%
# def csolve(a, b, c):  #корни функции
#     d= b**2 - 4*a*c
#     x1 = (-b+cmath.sqrt(d))/(2*a)
#     x2= (-b-cmath.sqrt(d))/(2*a)
#     return(x1, x2)

# %%
# x1,x2=csolve(5, 10, 30)
# print(f'Первый корень = ', x1,'; Второй корень = ', x2)
# Out:
# Первый корень =  (-1+2.23606797749979j) ; Второй корень =  (-1-2.23606797749979j)

# %%
# f1=5*x**2+10*x-30

# %%
# diff(f1)
# Out:
# 10⋅x + 10

# %%
# plot(f, (x, -2, 0))

# %%
# fun1=plot(f1, show=False)
# fun1.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 fun1=plot(f1, show=False)
#       2 fun1.show()
#
# NameError: name 'plot' is not defined

# %%
# x1,x2=solve (f1)  #корни
# print(f'Первый корень = ', x1.evalf(),'; Второй корень = ', x2.evalf())
# Out:
# Первый корень =  1.64575131106459 ; Второй корень =  -3.64575131106459

# %%
# # Вершина функции
# solve(f1)
# Out:
# [-1 + √7, -√7 - 1]
